# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
Hamoye_data=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='Latin-1')
Hamoye_data.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',index=False)

# %%
Hamoye_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
Hamoye_data.head(250)
# Out:
#      Area Code     Area  Item Code                    Item  Element Code  \
# 0            4  Algeria       2501              Population           511
# 1            4  Algeria       2501              Population          5301
# 2            4  Algeria       2901             Grand Total           664
# 3            4  Algeria       2901             Grand Total           674
# 4            4  Algeria       2901             Grand Total           684
# ..         ...      ...        ...                     ...           ...
# 245          4  Algeria       2542  Sugar (Raw Equivalent)           664
# 246          4  Algeria       2542  Sugar (Raw Equivalent)           674
# 247          4  Algeria       2542  Sugar (Raw Equivalent)           684
# 248          4  Algeria       2543       Sweeteners, Other          5511
# 249          4  Algeria       2543       Sweeteners, Other          5611
#
#                                     Element             Unit     Y2014  \
# ...

# %%
Hamoye_data.groupby('Item')['Y2014','Y2017'].sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
Hamoye_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
Hamoye_data['percent'] = (Hamoye_data['Y2016'] / Hamoye_data['Y2016'].sum()) * 100
print(Hamoye_data['percent'])
# Out:
# 0        4.998599e-01
# 1        0.000000e+00
# 2        4.156563e-02
# 3        1.167585e-03
# 4        9.540864e-04
#              ...
# 60938    4.067810e-04
# 60939    2.896774e-05
# 60940    3.698009e-05
# 60941    9.861358e-07
# 60942    3.698009e-07
# Name: percent, Length: 60943, dtype: float64

# %%
Hamoye_data.corr(method='pearson')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
# percent        0.005247   0.020109      0.023444  0.996081  0.995739
#
#                  Y2016     Y2017     Y2018   percent
# Area Code     0.005247  0.005006  0.005665  0.005247
# Item Code     0.020109  0.021494  0.021314  0.020109
# Element Code  0.023444  0.024254  0.024279  0.023444
# Y2014         0.996081  0.995230  0.994872  0.996081
# ...

# %%
Hamoye_data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
Hamoye_data.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
Hamoye_data.groupby(["Element" , "Area"]).sum().head(350)
# Out:
#                                        Area Code  Item Code  Element Code  \
# Element                  Area
# Domestic supply quantity Algeria             464     311204        614916
#                          Angola              826     316106        625518
#                          Benin              6148     310985        614916
#                          Botswana           2340     313766        620217
#                          Burkina Faso      27494     316106        625518
# ...                                          ...        ...           ...
# Import Quantity          Eswatini          24244     311265        650876
#                          Ethiopia          27370     308668        645265
#                          Ethiopia PDR        310      13835         28055
#                          Gabon              8436     305946        639654
#                          Gambia             7875     282017        589155
#
# ...

# %%
Hamoye_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 13 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# percent         59408 non-null float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 6.0+ MB

# %%
Hamoye_data.shape
# Out:
# (60943, 13)

# %%
Hamoye_data["Area"].unique()
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "CÃ\x83Â´te d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
len(Hamoye_data["Area"].unique().tolist())
# Out:
# 49

# %%
Hamoye_data["Element"].unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
Hamoye_data.loc[:,["Element","Area","Y2018"]]
# Out:
#                                       Element      Area     Y2018
# 0               Total Population - Both sexes   Algeria  42228.00
# 1                    Domestic supply quantity   Algeria      0.00
# 2               Food supply (kcal/capita/day)   Algeria   3322.00
# 3      Protein supply quantity (g/capita/day)   Algeria     91.83
# 4          Fat supply quantity (g/capita/day)   Algeria     77.28
# ...                                       ...       ...       ...
# 60938                                    Food  Zimbabwe     16.00
# 60939     Food supply quantity (kg/capita/yr)  Zimbabwe      1.08
# 60940           Food supply (kcal/capita/day)  Zimbabwe      1.00
# 60941  Protein supply quantity (g/capita/day)  Zimbabwe      0.04
# 60942      Fat supply quantity (g/capita/day)  Zimbabwe      0.01
#
# [60943 rows x 3 columns]

# %%
Hamoye_data.iloc[12:].sum().head()
# Out:
# Area Code                                                 8182499
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               163730468
# Item            Cereals - Excluding BeerCereals - Excluding Be...
# Element Code                                            232471408
# dtype: object

# %%
Hamoye_data.isnull().mean()
# Out:
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           0.026074
# Y2015           0.025401
# Y2016           0.025187
# Y2017           0.024712
# Y2018           0.023563
# percent         0.025187
# dtype: float64

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

# %%
pd.DataFrame(lst, columns= ['Age','Nationality','Overall'], index = [1,2,3])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
array
# Out:
# [[94, 89, 63], [93, 92, 48], [92, 94, 56]]

# %%
array[:1]
# Out:
# [[94, 89, 63]]

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
x = y[1][1]

# %%
x
# Out:
# 8
